# %%
import pandas as pd
inst = pd.read_csv('https://www.xetra.com/resource/blob/1528/c9dd49f746232ab52133fc9b31ef8577/data/t7-xetr-allTradableInstruments.csv', 
                   sep=';', skiprows=2, usecols=['instrument', 'Mnemonic', 'Instrument Type', 'Product Assignment Group Description', 'Primary Market MIC Code'])
inst[(inst['Instrument Type']=='ETF') & (inst['Primary Market MIC Code']=='XETR')]
# Out:
#                      instrument Mnemonic Product Assignment Group Description  \
# 87                   XTR.DAX 1C     DBXD       EXCHANGE TRADED FUNDS - PASSIV
# 88    XTR.SHORTDAX DAILY SW. 1C     DXSN       EXCHANGE TRADED FUNDS - PASSIV
# 90    XTR.SHORTDAX X2 DA.SW. 1C     DBPD       EXCHANGE TRADED FUNDS - PASSIV
# 91        XTR.LEVDAX DA.SWAP 1C     DBPE       EXCHANGE TRADED FUNDS - PASSIV
# 463    ISH.MSCI.BRAZIL U.ETF DE     4BRZ                   ETF - CURRENCY USD
# 511    IM-I.MO.US EN.IN.MLP ADZ     SMLP       EXCHANGE TRADED FUNDS - PASSIV
# 512    IM-I.MO.US EN.IN.MLP DDZ     SMLD       EXCHANGE TRADED FUNDS - PASSIV
# 753   WISDOMTR.AT1 COC.B.HEODDZ     WTEB       EXCHANGE TRADED FUNDS - RENTEN
# 765    WISDOMTR. ART.INT. DLADZ     WTI2       EXCHANGE TRADED FUNDS - PASSIV
# 1320  UBS ETFS-CMCI C.SF LSAACC     UEQ3                   ETF - CURRENCY GBP
# 1361  UBS(I)-SOL.G.O.E.U.E.ADDL     UBUB       EXCHANGE TRADED FUNDS - PASSIV
# ...
