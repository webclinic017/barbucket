# %%
# Imports

import pandas as pd

from tinydb import TinyDB, Query
from tinydb.storages import JSONStorage
from tinydb.middlewares import CachingMiddleware

from tqdm import tqdm_notebook as tqdm

# %% [markdown]
# # Create databse

# %%
# Column names

symbol_df = pd.DataFrame(columns=['Symbol', 'Name', 'Symbol2', 'Currency', 'Exchange', 'Status'])

# %%
"""
Possible status valus:
'no_data'
'data_ends:yyyy-mm-dd'
'error:error_message'
"""

# %%
# Exchanges

exchanges = {
    'FWB': 'ib_fwb_etfs.csv',
    'LSE': 'ib_lse_etfs.csv',
    'LSEETF': 'ib_lse-etf_etfs.csv',
    'IBIS': 'ib_xetra_etfs.csv'
}

# %%
# Read contracts info from file to df

for ex, file in exchanges.items():
    one_ex_data = pd.read_csv(file, delimiter=';')
    # todo: clean symbol names
    one_ex_data['Exchange'] = ex
    contracts_df = contracts_df.append(one_ex_data, ignore_index=True, sort=True)
contracts_df.describe()
# Out:
#        Currency Exchange                                   Name Status Symbol  \
# count      5323     5323                                   5323      0   5323
# unique        3        4                                   2284      0   3732
# top         EUR      LSE  WisdomTree US Equity Income UCITS ETF    NaN   STAW
# freq       3024     1827                                     12    NaN      4
#
#        Symbol2
# count     5323
# unique    3955
# top       3DES
# freq         3

# %%
# Write df to CSV

contracts_df.to_csv('contracts_database.csv', sep=';')

# %%
# Write list to textfile

# df = contracts_database[contracts_database['Symbol']!=contracts_database['Symbol2']]
df = contracts_df.loc[contracts_df['exchange']=='fwb', 'Symbol']
symbol_list = df.tolist()

file = open('symbollist.txt', 'w+')
for symbol in symbol_list:
    file.write(symbol+'\n')
file.close()

# %%
# TODO: Create development database

# %%
# Write to tinydb

# ----- DANGER ZONE! -----
# 
# contracts_db = TinyDB('contracts_db.json', storage=CachingMiddleware(JSONStorage))
# 
# for index, row in tqdm(contracts_df.iterrows()):
#     contracts_db.insert({'Id': index, 
#                       'Symbol': row['Symbol'], 
#                       'Name': row['Name'], 
#                       'Currency': row['Currency'], 
#                       'Exchange': row['Exchange'],
#                       'Status': 'no_data'
#                      })
# contracts_db.close()
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %% [markdown]
# # Modify database

# %%
# Update certain status values

contracts_db = TinyDB('contracts_db.json')
my_query = Query()
# contracts_db.update({'Status': 'untouched'}, 
#                  my_query.Status == "Historical Market Data Service error message:No market data permissions for SWB STK")
contracts_db.update({'Status': 'no_data'}, my_query.Status != 'bullshit')
contracts_db.close()

# %% [markdown]
# # Analyse database data

# %%
# Read contracts data to df

contracts_db = TinyDB('contracts_db.json')
data_list = contracts_db.all()
contracts_db.close()

data_string = str(data_list)
data_string = data_string.replace("-'bP'", "-bP")
data_string = data_string.replace("MOODY'S", "MOODYS")
data_string = data_string.replace("'", '"')

df = pd.read_json(data_string, orient='records')
df
# Out:
#         Id Symbol                                               Name Currency  \
# 0        0   BNQF  Collateralized ETC on RICI Enhanced Gas Oil TR...      EUR
# 1        1    CNB  Lyxor Euro Corporate Bond Ex Financials UCITS ETF      EUR
# 2        2   UEF5  UBS ETF - MSCI Emerging Markets Socially Respo...      EUR
# 3        3   GOMA  BNP Paribas Easy Barclays Euro Government Infl...      EUR
# 4        4   X0BM           Coba ETC -2 x Platinum Daily Short Index      EUR
# ...    ...    ...                                                ...      ...
# 5318  5318   EXX1        iShares EURO STOXX Banks 30-15 UCITS ETF DE      EUR
# 5319  5319   10AM  AMUNDI INDEX BARCLAYS GLOBAL AGG 500M UCITS ET...      EUR
# 5320  5320   X0CW                    Coba ETN -15x BUNDF Daily Short      EUR
# 5321  5321   X0B3                     Coba ETC 3x WTI Oil Daily Long      EUR
# 5322  5322   XBJJ                            ETFS Long AUD Short EUR      EUR
#
#      Exchange                                             Status
# 0         FWB        Market data farm connection is OK:usfarm.nj
# 1         FWB                                         2019-09-29
# 2         FWB                                         2019-09-29
# 3         FWB                                         2019-09-29
# 4         FWB                                         2019-09-29
# ...       ...                                                ...
# 5318     IBIS  Historical Market Data Service error message:N...
# 5319     IBIS  Historical Market Data Service error message:N...
# 5320     IBIS                                           Finished
# 5321     IBIS                                           Finished
# 5322     IBIS                                           Finished
#
# [5323 rows x 6 columns]

# %%
# Group by exchange

dfe = df.groupby('Exchange').count()
dfe
# Out:
#             Id  Symbol  Name  Currency  Status
# Exchange
# FWB       1349    1349  1349      1349    1349
# IBIS      1266    1266  1266      1266    1266
# LSE       1827    1827  1827      1827    1827
# LSEETF     881     881   881       881     881

# %%
# Group by status

dfs = df.groupby('Status').count()
dfs
# Out:
#                                                       Id  Symbol  Name  \
# Status
# 2019-09-29                                           956     956   956
# Finished                                            2807    2807  2807
# Historical Market Data Service error message:HM...     1       1     1
# Historical Market Data Service error message:HM...     1       1     1
# Historical Market Data Service error message:HM...     1       1     1
# ...                                                  ...     ...   ...
# Historical Market Data Service error message:No...     1       1     1
# Historical Market Data Service error message:No...     7       7     7
# Market data farm connection is OK:eufarm               1       1     1
# Market data farm connection is OK:usfarm.nj            1       1     1
# No security definition has been found for the r...    54      54    54
#
#                                                     Currency  Exchange
# Status
# 2019-09-29                                               956       956
# Finished                                                2807      2807
# Historical Market Data Service error message:HM...         1         1
# Historical Market Data Service error message:HM...         1         1
# Historical Market Data Service error message:HM...         1         1
# ...                                                      ...       ...
# Historical Market Data Service error message:No...         1         1
# Historical Market Data Service error message:No...         7         7
# Market data farm connection is OK:eufarm                   1         1
# Market data farm connection is OK:usfarm.nj                1         1
# No security definition has been found for the r...        54        54
#
# [358 rows x 5 columns]

# %%
# Group by status + exchange

dfse = df.groupby(['Exchange', 'Status']).count()
dfse
# Out:
#                                                               Id  Symbol  \
# Exchange Status
# FWB      Finished                                            375     375
#          Historical Market Data Service error message:No...  962     962
#          Historical Market Data Service error message:No...    2       2
#          Market data farm connection is OK:usfarm              1       1
#          No security definition has been found for the r...    9       9
# ...                                                          ...     ...
# LSEETF   Historical Market Data Service error message:HM...    1       1
#          Historical Market Data Service error message:No...    1       1
#          Historical Market Data Service error message:No...    1       1
#          Historical Market Data Service error message:No...    2       2
#          Historical Market Data Service error message:No...    1       1
#
#                                                              Name  Currency
# Exchange Status
# FWB      Finished                                             375       375
#          Historical Market Data Service error message:No...   962       962
#          Historical Market Data Service error message:No...     2         2
#          Market data farm connection is OK:usfarm               1         1
#          No security definition has been found for the r...     9         9
# ...                                                           ...       ...
# LSEETF   Historical Market Data Service error message:HM...     1         1
#          Historical Market Data Service error message:No...     1         1
#          Historical Market Data Service error message:No...     1         1
#          Historical Market Data Service error message:No...     2         2
#          Historical Market Data Service error message:No...     1         1
#
# [364 rows x 4 columns]

# %%
df.loc[(df['Exchange']=='LSE') & (df['Status']!='Finished')]
# Out:
#         Id  Symbol                                               Name  \
# 1354  1354    4GLD                                         Xetra-Gold
# 1358  1358    0I9M               Direxion Daily Retail Bull 3X Shares
# 1361  1361    EQUA   BNP PARIBAS EASY Equity Quality Europe UCITS ETF
# 1369  1369  JBGOUA                GAM Precious Metals - Physical Gold
# 1373  1373    E903                        ComStage 1 DivDAX UCITS ETF
# ...    ...     ...                                                ...
# 3141  3141    XGII  Xtrackers II Global Inflation-Linked Bond UCIT...
# 3150  3150   UKUKD              UBS ETF MSCI United Kingdom UCITS ETF
# 3158  3158    E908                        ComStage 1 TecDAX UCITS ETF
# 3168  3168  JBGOGX                GAM Precious Metals - Physical Gold
# 3174  3174   ELOVU   UBS ETF-Factor MSCI EMU Low Volatility UCITS ETF
#
#      Currency Exchange                                             Status
# 1354      EUR      LSE  Historical Market Data Service error message:H...
# 1358      USD      LSE  Historical Market Data Service error message:H...
# 1361      EUR      LSE  Historical Market Data Service error message:H...
# 1369      USD      LSE  Historical Market Data Service error message:H...
# 1373      EUR      LSE  Historical Market Data Service error message:H...
# ...       ...      ...                                                ...
# 3141      EUR      LSE  Historical Market Data Service error message:H...
# 3150      GBP      LSE  Historical Market Data Service error message:H...
# 3158      EUR      LSE  Historical Market Data Service error message:H...
# 3168      GBP      LSE  Historical Market Data Service error message:H...
# 3174      USD      LSE  Historical Market Data Service error message:H...
#
# [341 rows x 6 columns]
