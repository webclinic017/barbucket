# %%
# Imports

from ibpythonic import ibConnection, message
from ibapi.contract import Contract

from time import sleep, strftime
from datetime import datetime
import pickle
import os
from multiprocessing import Pool

import workers

import pandas as pd
import numpy as np

from tinydb import TinyDB, Query

from tqdm import tqdm_notebook as tqdm

# %%
# Create contract object

def makeStkContract(contractTuple):
    newContract = Contract()
    newContract.symbol = contractTuple[0]
    newContract.secType = contractTuple[1]
    newContract.exchange = contractTuple[2]
    newContract.currency = contractTuple[3]
    return newContract

# %%
# Control variables declaration

bar_data_list = []
busy = False
active_contract_id = 0

# %%
# Historical data handler

def my_hist_data_handler(msg):
    global bar_data_list

    # If message does not belong to current contract, leave this function
    if int(msg.reqId) != active_contract_id:
        print('hist_data_handler: Msg does not belong to active contract: ' + str(msg))
        return
    
    # print(msg)
    bar_data_list.append(msg.bar)

# %%
# End of historical data handler

def my_hist_data_end_handler(msg):
    # print('hist_data_end_handler: ' + str(msg))
    global bar_data_list
    global busy
    global active_contract_id

    print('data retrieval complete.')
        
    # If message does not belong to current contract, leave this function
    if int(msg.reqId) != active_contract_id:
        print('hist_data_end_handler: Msg does not belong to active contract: ' + str(msg))
        return

    # Merge collected data into dataframe
    df_new = pd.DataFrame(columns=('date', 'open', 'high', 'low', 'close', 'volume'))
    for bar in bar_data_list:
        dashed_date = bar.date[:4] + '-' + bar.date[4:6] + '-' + bar.date[6:]
        row = {'date': dashed_date, 'open': bar.open, 'high': bar.high, 'low': bar.low, 'close': bar.close, 'volume': bar.volume}
        df_new = df_new.append(row, ignore_index=True)
    # df_new.loc[:, 'date'] = pd.to_datetime(df_new.date, format='%Y%m%d') #'%Y%m%d  %H:%M:%S'
    df_new = df_new.set_index('date')

    # Check if there is already existing data
    contracts_db = TinyDB('contracts_db.json')
    my_query = Query()
    result = contracts_db.search(my_query.Id == active_contract_id)
    contracts_db.close()
    current_contract = result[0]        
    contract_status = current_contract['Status']
    contract_symbol = current_contract['Symbol']
    contract_exchange = current_contract['Exchange']

    # Append to existing file or create new file
    filename = '/Users/martin/Google Drive/data/screener/' + contract_symbol + '_' + contract_exchange + '.csv'
    if contract_status.startswith('data_ends:'):
        df_old = pd.read_csv(filename, index_col='date')
        df_combined = df_new.combine_first(df_old)
        os.remove(filename)
        df_combined.to_csv(filename)
    else:
        if os.path.exists(filename):
            os.remove(filename)
        df_new.to_csv(filename)

    # write finished info to contracts database
        # Todo: use last day of data instead of today
    timestamp_now = datetime.now()
    string_now = timestamp_now.strftime('%Y-%m-%d') 
    contracts_db = TinyDB('contracts_db.json')
    my_query = Query()
    contracts_db.update({'Status': 'data_ends:'+string_now}, my_query.Id == active_contract_id)
    contracts_db.close()

    print(contract_symbol + '_' + contract_exchange + ' successful.')

    bar_data_list = []
    active_contract_id = 0
    busy = False

# %%
# Error handler

def my_error_handler(msg):
    # print('my_error_handler: ' + str(msg))
    
    global bar_data_list
    global busy
    global active_contract_id
    
    # If message does not belong to current contract, leave this function
    if int(msg.id) != active_contract_id:
        print('error_handler: Msg does not belong to active contract: ' + str(msg))
        return
        
    # write msg info to contracts database
    contracts_db = TinyDB('contracts_db.json')
    my_query = Query()
    status = 'Error:' + str(msg.errorCode) + '_' + str(msg.errorMsg)
    status = status.replace("'", "")
    contracts_db.update({'Status': status}, my_query.Id == active_contract_id)

    # get current contract info
    result = contracts_db.search(my_query.Id == active_contract_id)
    current_contract = result[0]        
    contract_symbol = current_contract['Symbol']
    contract_exchange = current_contract['Exchange']
    contracts_db.close()
    
    print(contract_symbol + '_' + contract_exchange + ' ' + status)
        
    bar_data_list = []
    active_contract_id = 0
    busy = False

# %%
# Data retrieval constants

endtime = strftime('%Y%m%d %H:%M:%S')
start_id = 5000
end_id = 5323

# %%
# Create connection object

con = ibConnection(port=7497)
con.register(my_hist_data_handler, message.historicalData)
con.register(my_hist_data_end_handler, message.historicalDataEnd)
con.register(my_error_handler, message.error)
# Out:
# True

# %%
# Main function

con.connect()
    
for index in tqdm(range(start_id, end_id)):
        # Todo: Make the loop stoppable
        # Todo: Add timeout
    global busy
    global active_contract_id
    
    # Get contract data from contracts db
    contracts_db = TinyDB('contracts_db.json')
    my_query = Query()
    result = contracts_db.search(my_query.Id == index)
    contracts_db.close()
    current_contract = result[0]
    contract_status = current_contract['Status']       
    debug_string = str(index) + ': ' + current_contract['Symbol'] + '_' + current_contract['Exchange'] + ' requesting. '
    print(debug_string, end='')
    
    # Check if CSV file is already present
        # Todo: Skip contract on certain error status, eg. tws does not know this contract
        # todo: exit on certain error status, eg no connection
    if contract_status.startswith('data_ends:'):
        start_date = (contract_status.split(':'))[1]
        end_date = datetime.today().strftime('%Y-%m-%d')
        ndays = np.busday_count(start_date, end_date)
        if ndays <= 1:
            print('data is up to date. ' + str(ndays))
            continue
        ndays += 4
        req_string = str(ndays) + ' D'  
    else:
        req_string = "10 Y"
    
    if current_contract['Symbol'] == 'XGSD' and current_contract['Exchange'] == 'LSE':
        print('Skipping XGSD_LSE.')
        continue
        # Todo: Fix me
    
    # Create contract and request data
    contractTuple = (current_contract['Symbol'], 'STK', current_contract['Exchange'], current_contract['Currency'])
    stkContract = makeStkContract(contractTuple)
    active_contract_id = index
    busy = True
    con.reqHistoricalData(active_contract_id,stkContract,endtime,req_string,'1 day','MIDPOINT',1,1, keepUpToDate=False, chartOptions=[])
    
    # Wait for data download and storage
    while busy is True:
        sleep(0.2)
    sleep(0.2)
    print('-------------------------')
    
print('******** All done. ********')
con.disconnect()
# Out:
# error_handler: Msg does not belong to active contract: <error id=-1, errorCode=2104, errorMsg=Market data farm connection is OK:usfarm.nj>
# error_handler: Msg does not belong to active contract: <error id=-1, errorCode=2104, errorMsg=Market data farm connection is OK:eufarm>
# error_handler: Msg does not belong to active contract: <error id=-1, errorCode=2104, errorMsg=Market data farm connection is OK:cashfarm>
# error_handler: Msg does not belong to active contract: <error id=-1, errorCode=2104, errorMsg=Market data farm connection is OK:usfarm>
# error_handler: Msg does not belong to active contract: <error id=-1, errorCode=2106, errorMsg=HMDS data farm connection is OK:euhmds>
# error_handler: Msg does not belong to active contract: <error id=-1, errorCode=2106, errorMsg=HMDS data farm connection is OK:ushmds>
# error_handler: Msg does not belong to active contract: <error id=-1, errorCode=2158, errorMsg=Sec-def data farm connection is OK:secdefnj>
# HBox(children=(IntProgress(value=0, max=323), HTML(value='')))
# 5000: C051_IBIS requesting. data retrieval complete.
# C051_IBIS successful.
# -------------------------
# 5001: X04J_IBIS requesting. data retrieval complete.
# X04J_IBIS successful.
# -------------------------
# 5002: 0LJH_IBIS requesting. 0LJH_IBIS Error:200_No security definition has been found for the request
# -------------------------
# 5003: FRNU_IBIS requesting. data retrieval complete.
# FRNU_IBIS successful.
# -------------------------
# 5004: C6E_IBIS requesting. data retrieval complete.
# C6E_IBIS successful.
# -------------------------
# 5005: FRC3_IBIS requesting. data retrieval complete.
# FRC3_IBIS successful.
# -------------------------
# 5006: WTEI_IBIS requesting. data retrieval complete.
# WTEI_IBIS successful.
# -------------------------
# 5007: EL4Q_IBIS requesting. data retrieval complete.
# EL4Q_IBIS successful.
# -------------------------
# 5008: 4RUA_IBIS requesting. 4RUA_IBIS Error:200_No security definition has been found for the request
# -------------------------
# 5009: EMMV_IBIS requesting. data retrieval complete.
# EMMV_IBIS successful.
# -------------------------
# 5010: X0CK_IBIS requesting. data retrieval complete.
# X0CK_IBIS successful.
# -------------------------
# 5011: CD40_IBIS requesting. data retrieval complete.
# CD40_IBIS successful.
# -------------------------
# 5012: OD7H_IBIS requesting. data retrieval complete.
# OD7H_IBIS successful.
# -------------------------
# 5013: E907_IBIS requesting. data retrieval complete.
# E907_IBIS successful.
# -------------------------
# 5014: 9GAM_IBIS requesting. data retrieval complete.
# 9GAM_IBIS successful.
# -------------------------
# 5015: EL4D_IBIS requesting. data retrieval complete.
# EL4D_IBIS successful.
# -------------------------
# 5016: OD7B_IBIS requesting. data retrieval complete.
# OD7B_IBIS successful.
# -------------------------
# 5017: XHYA_IBIS requesting. data retrieval complete.
# XHYA_IBIS successful.
# -------------------------
# 5018: XDWM_IBIS requesting. data retrieval complete.
# XDWM_IBIS successful.
# -------------------------
# 5019: H4ZP_IBIS requesting. data retrieval complete.
# H4ZP_IBIS successful.
# -------------------------
# 5020: EL4J_IBIS requesting. data retrieval complete.
# EL4J_IBIS successful.
# -------------------------
# 5021: UEFZ_IBIS requesting. data retrieval complete.
# UEFZ_IBIS successful.
# -------------------------
# 5022: FTGU_IBIS requesting. data retrieval complete.
# FTGU_IBIS successful.
# -------------------------
# 5023: 10AK_IBIS requesting. data retrieval complete.
# 10AK_IBIS successful.
# -------------------------
# 5024: X0B9_IBIS requesting. data retrieval complete.
# X0B9_IBIS successful.
# -------------------------
# 5025: PPP_IBIS requesting. data retrieval complete.
# PPP_IBIS successful.
# -------------------------
# 5026: UIMM_IBIS requesting. data retrieval complete.
# UIMM_IBIS successful.
# -------------------------
# 5027: B4N2_IBIS requesting. data retrieval complete.
# B4N2_IBIS successful.
# -------------------------
# 5028: X0CF_IBIS requesting. data retrieval complete.
# X0CF_IBIS successful.
# -------------------------
# 5029: EXX2_IBIS requesting. data retrieval complete.
# EXX2_IBIS successful.
# -------------------------
# 5030: WTD7_IBIS requesting. data retrieval complete.
# WTD7_IBIS successful.
# -------------------------
# 5031: UIM7_IBIS requesting. data retrieval complete.
# UIM7_IBIS successful.
# -------------------------
# 5032: SRIJ_IBIS requesting. data retrieval complete.
# SRIJ_IBIS successful.
# -------------------------
# 5033: MKTN_IBIS requesting. data retrieval complete.
# MKTN_IBIS successful.
# -------------------------
# 5034: DBX1_IBIS requesting. data retrieval complete.
# DBX1_IBIS successful.
# -------------------------
# 5035: XBO2_IBIS requesting. data retrieval complete.
# XBO2_IBIS successful.
# -------------------------
# 5036: X0D9_IBIS requesting. data retrieval complete.
# X0D9_IBIS successful.
# -------------------------
# 5037: X049_IBIS requesting. data retrieval complete.
# X049_IBIS successful.
# -------------------------
# 5038: E573_IBIS requesting. data retrieval complete.
# E573_IBIS successful.
# -------------------------
# 5039: 4RT7_IBIS requesting. 4RT7_IBIS Error:200_No security definition has been found for the request
# -------------------------
# 5040: 00XM_IBIS requesting. data retrieval complete.
# 00XM_IBIS successful.
# -------------------------
# 5041: IROB_IBIS requesting. data retrieval complete.
# IROB_IBIS successful.
# -------------------------
# 5042: XAD5_IBIS requesting. data retrieval complete.
# XAD5_IBIS successful.
# -------------------------
# 5043: H4Z9_IBIS requesting. data retrieval complete.
# H4Z9_IBIS successful.
# -------------------------
# 5044: FIN_IBIS requesting. data retrieval complete.
# FIN_IBIS successful.
# -------------------------
# 5045: UBUU_IBIS requesting. data retrieval complete.
# UBUU_IBIS successful.
# -------------------------
# 5046: UEFL_IBIS requesting. data retrieval complete.
# UEFL_IBIS successful.
# -------------------------
# 5047: C030_IBIS requesting. data retrieval complete.
# C030_IBIS successful.
# -------------------------
# 5048: EXV6_IBIS requesting. data retrieval complete.
# EXV6_IBIS successful.
# -------------------------
# 5049: FGEQ_IBIS requesting. FGEQ_IBIS Error:200_No security definition has been found for the request
# -------------------------
# 5050: EXXW_IBIS requesting. data retrieval complete.
# EXXW_IBIS successful.
# -------------------------
# 5051: AHYE_IBIS requesting. data retrieval complete.
# AHYE_IBIS successful.
# -------------------------
# 5052: SEAC_IBIS requesting. data retrieval complete.
# SEAC_IBIS successful.
# -------------------------
# 5053: DX2S_IBIS requesting. data retrieval complete.
# DX2S_IBIS successful.
# -------------------------
# 5054: MUAT_IBIS requesting. data retrieval complete.
# MUAT_IBIS successful.
# -------------------------
# 5055: X0D8_IBIS requesting. data retrieval complete.
# X0D8_IBIS successful.
# -------------------------
# 5056: DBXJ_IBIS requesting. data retrieval complete.
# DBXJ_IBIS successful.
# -------------------------
# 5057: C062_IBIS requesting. data retrieval complete.
# C062_IBIS successful.
# -------------------------
# 5058: 0LJJ_IBIS requesting. data retrieval complete.
# 0LJJ_IBIS successful.
# -------------------------
# 5059: EFQ2_IBIS requesting. data retrieval complete.
# EFQ2_IBIS successful.
# -------------------------
# 5060: CRN_IBIS requesting. data retrieval complete.
# CRN_IBIS successful.
# -------------------------
# 5061: H4ZC_IBIS requesting. data retrieval complete.
# H4ZC_IBIS successful.
# -------------------------
# 5062: X00I_IBIS requesting. data retrieval complete.
# X00I_IBIS successful.
# -------------------------
# 5063: VAGE_IBIS requesting. data retrieval complete.
# VAGE_IBIS successful.
# -------------------------
# 5064: CCNV_IBIS requesting. data retrieval complete.
# CCNV_IBIS successful.
# -------------------------
# 5065: CST_IBIS requesting. data retrieval complete.
# CST_IBIS successful.
# -------------------------
# 5066: BYBE_IBIS requesting. data retrieval complete.
# BYBE_IBIS successful.
# -------------------------
# 5067: 00XJ_IBIS requesting. data retrieval complete.
# 00XJ_IBIS successful.
# -------------------------
# 5068: X006_IBIS requesting. data retrieval complete.
# X006_IBIS successful.
# -------------------------
# 5069: EXVM_IBIS requesting. data retrieval complete.
# EXVM_IBIS successful.
# -------------------------
# 5070: GSCE_IBIS requesting. data retrieval complete.
# GSCE_IBIS successful.
# -------------------------
# 5071: UETE_IBIS requesting. data retrieval complete.
# UETE_IBIS successful.
# -------------------------
# 5072: SMLC_IBIS requesting. data retrieval complete.
# SMLC_IBIS successful.
# -------------------------
# 5073: EXS1_IBIS requesting. data retrieval complete.
# EXS1_IBIS successful.
# -------------------------
# 5074: UBUN_IBIS requesting. data retrieval complete.
# UBUN_IBIS successful.
# -------------------------
# 5075: GBSE1_IBIS requesting. data retrieval complete.
# GBSE1_IBIS successful.
# -------------------------
# 5076: UIQI_IBIS requesting. UIQI_IBIS Error:162_Historical Market Data Service error message:No market data permissions for BVME.ETF STK
# -------------------------
# 5077: F750_IBIS requesting. data retrieval complete.
# F750_IBIS successful.
# -------------------------
# 5078: EXXU_IBIS requesting. data retrieval complete.
# EXXU_IBIS successful.
# -------------------------
# 5079: B4N7_IBIS requesting. data retrieval complete.
# B4N7_IBIS successful.
# -------------------------
# 5080: VZLD_IBIS requesting. data retrieval complete.
# VZLD_IBIS successful.
# -------------------------
# 5081: CU1_IBIS requesting. data retrieval complete.
# CU1_IBIS successful.
# -------------------------
# 5082: UEFE_IBIS requesting. data retrieval complete.
# UEFE_IBIS successful.
# -------------------------
# 5083: UIQL_IBIS requesting. data retrieval complete.
# UIQL_IBIS successful.
# -------------------------
# 5084: 0LJC_IBIS requesting. data retrieval complete.
# 0LJC_IBIS successful.
# -------------------------
# 5085: 10AJ_IBIS requesting. data retrieval complete.
# 10AJ_IBIS successful.
# -------------------------
# 5086: DBPE_IBIS requesting. data retrieval complete.
# DBPE_IBIS successful.
# -------------------------
# 5087: H4ZA_IBIS requesting. data retrieval complete.
# H4ZA_IBIS successful.
# -------------------------
# 5088: F751_IBIS requesting. data retrieval complete.
# F751_IBIS successful.
# -------------------------
# 5089: X507_IBIS requesting. data retrieval complete.
# X507_IBIS successful.
# -------------------------
# 5090: XHYG_IBIS requesting. data retrieval complete.
# XHYG_IBIS successful.
# -------------------------
# 5091: EL4C_IBIS requesting. data retrieval complete.
# EL4C_IBIS successful.
# -------------------------
# 5092: XGIU_IBIS requesting. data retrieval complete.
# XGIU_IBIS successful.
# -------------------------
# 5093: X0D1_IBIS requesting. data retrieval complete.
# X0D1_IBIS successful.
# -------------------------
# 5094: CN1_IBIS requesting. data retrieval complete.
# CN1_IBIS successful.
# -------------------------
# 5095: 0LJG_IBIS requesting. 0LJG_IBIS Error:200_No security definition has been found for the request
# -------------------------
# 5096: 4RUC_IBIS requesting. data retrieval complete.
# 4RUC_IBIS successful.
# -------------------------
# 5097: X0D7_IBIS requesting. data retrieval complete.
# X0D7_IBIS successful.
# -------------------------
# 5098: X0BH_IBIS requesting. data retrieval complete.
# X0BH_IBIS successful.
# -------------------------
# 5099: C053_IBIS requesting. data retrieval complete.
# C053_IBIS successful.
# -------------------------
# 5100: C006_IBIS requesting. data retrieval complete.
# C006_IBIS successful.
# -------------------------
# 5101: DXSI_IBIS requesting. data retrieval complete.
# DXSI_IBIS successful.
# -------------------------
# 5102: H41K_IBIS requesting. data retrieval complete.
# H41K_IBIS successful.
# -------------------------
# 5103: SHEME_IBIS requesting. data retrieval complete.
# SHEME_IBIS successful.
# -------------------------
# 5104: C078_IBIS requesting. data retrieval complete.
# C078_IBIS successful.
# -------------------------
# 5105: OD7N_IBIS requesting. data retrieval complete.
# OD7N_IBIS successful.
# -------------------------
# 5106: LVO1_IBIS requesting. data retrieval complete.
# LVO1_IBIS successful.
# -------------------------
# 5107: XUTC_IBIS requesting. data retrieval complete.
# XUTC_IBIS successful.
# -------------------------
# 5108: FOO_IBIS requesting. data retrieval complete.
# FOO_IBIS successful.
# -------------------------
# 5109: H4ZU_IBIS requesting. data retrieval complete.
# H4ZU_IBIS successful.
# -------------------------
# 5110: STXH_IBIS requesting. data retrieval complete.
# STXH_IBIS successful.
# -------------------------
# 5111: X0CE_IBIS requesting. data retrieval complete.
# X0CE_IBIS successful.
# -------------------------
# 5112: XAIN_IBIS requesting. data retrieval complete.
# XAIN_IBIS successful.
# -------------------------
# 5113: OESB_IBIS requesting. data retrieval complete.
# OESB_IBIS successful.
# -------------------------
# 5114: UEF6_IBIS requesting. data retrieval complete.
# UEF6_IBIS successful.
# -------------------------
# 5115: CCXAE_IBIS requesting. data retrieval complete.
# CCXAE_IBIS successful.
# -------------------------
# 5116: XD5E_IBIS requesting. data retrieval complete.
# XD5E_IBIS successful.
# -------------------------
# 5117: ELFW_IBIS requesting. data retrieval complete.
# ELFW_IBIS successful.
# -------------------------
# 5118: DXSQ_IBIS requesting. data retrieval complete.
# DXSQ_IBIS successful.
# -------------------------
# 5119: JPN_IBIS requesting. data retrieval complete.
# JPN_IBIS successful.
# -------------------------
# 5120: DSD_IBIS requesting. data retrieval complete.
# DSD_IBIS successful.
# -------------------------
# 5121: C3M_IBIS requesting. data retrieval complete.
# C3M_IBIS successful.
# -------------------------
# 5122: ES5R_IBIS requesting. data retrieval complete.
# ES5R_IBIS successful.
# -------------------------
# 5123: MDBU_IBIS requesting. data retrieval complete.
# MDBU_IBIS successful.
# -------------------------
# 5124: SCHE_IBIS requesting. data retrieval complete.
# SCHE_IBIS successful.
# -------------------------
# 5125: XDJP_IBIS requesting. data retrieval complete.
# XDJP_IBIS successful.
# -------------------------
# 5126: WTDS_IBIS requesting. data retrieval complete.
# WTDS_IBIS successful.
# -------------------------
# 5127: VWRL_IBIS requesting. data retrieval complete.
# VWRL_IBIS successful.
# -------------------------
# 5128: BATE_IBIS requesting. data retrieval complete.
# BATE_IBIS successful.
# -------------------------
# 5129: C076_IBIS requesting. data retrieval complete.
# C076_IBIS successful.
# -------------------------
# 5130: X0B8_IBIS requesting. data retrieval complete.
# X0B8_IBIS successful.
# -------------------------
# 5131: OSXC_IBIS requesting. data retrieval complete.
# OSXC_IBIS successful.
# -------------------------
# 5132: C073_IBIS requesting. data retrieval complete.
# C073_IBIS successful.
# -------------------------
# 5133: X0CI_IBIS requesting. data retrieval complete.
# X0CI_IBIS successful.
# -------------------------
# 5134: X0DI_IBIS requesting. data retrieval complete.
# X0DI_IBIS successful.
# -------------------------
# 5135: XDWI_IBIS requesting. data retrieval complete.
# XDWI_IBIS successful.
# -------------------------
# 5136: 8530_IBIS requesting. 8530_IBIS Error:162_Historical Market Data Service error message:No market data permissions for SWB STK
# -------------------------
# 5137: XDEM_IBIS requesting. data retrieval complete.
# XDEM_IBIS successful.
# -------------------------
# 5138: EL4T_IBIS requesting. data retrieval complete.
# EL4T_IBIS successful.
# -------------------------
# 5139: X00B_IBIS requesting. data retrieval complete.
# X00B_IBIS successful.
# -------------------------
# 5140: B4N1_IBIS requesting. data retrieval complete.
# B4N1_IBIS successful.
# -------------------------
# 5141: XMOV_IBIS requesting. data retrieval complete.
# XMOV_IBIS successful.
# -------------------------
# 5142: VLUD_IBIS requesting. data retrieval complete.
# VLUD_IBIS successful.
# -------------------------
# 5143: XSXE_IBIS requesting. data retrieval complete.
# XSXE_IBIS successful.
# -------------------------
# 5144: C2U_IBIS requesting. data retrieval complete.
# C2U_IBIS successful.
# -------------------------
# 5145: EJAH_IBIS requesting. data retrieval complete.
# EJAH_IBIS successful.
# -------------------------
# 5146: X00L_IBIS requesting. data retrieval complete.
# X00L_IBIS successful.
# -------------------------
# 5147: X00C_IBIS requesting. data retrieval complete.
# X00C_IBIS successful.
# -------------------------
# 5148: 4RUJ_IBIS requesting. data retrieval complete.
# 4RUJ_IBIS successful.
# -------------------------
# 5149: EXH5_IBIS requesting. data retrieval complete.
# EXH5_IBIS successful.
# -------------------------
# 5150: C066_IBIS requesting. data retrieval complete.
# C066_IBIS successful.
# -------------------------
# 5151: CI1_IBIS requesting. data retrieval complete.
# CI1_IBIS successful.
# -------------------------
# 5152: XG71_IBIS requesting. data retrieval complete.
# XG71_IBIS successful.
# -------------------------
# 5153: ESEH_IBIS requesting. data retrieval complete.
# ESEH_IBIS successful.
# -------------------------
# 5154: AUT_IBIS requesting. data retrieval complete.
# AUT_IBIS successful.
# -------------------------
# 5155: X00S_IBIS requesting. data retrieval complete.
# X00S_IBIS successful.
# -------------------------
# 5156: XAD4_IBIS requesting. data retrieval complete.
# XAD4_IBIS successful.
# -------------------------
# 5157: OOEB_IBIS requesting. data retrieval complete.
# OOEB_IBIS successful.
# -------------------------
# 5158: BSX_IBIS requesting. data retrieval complete.
# BSX_IBIS successful.
# -------------------------
# 5159: REUSE_IBIS requesting. data retrieval complete.
# REUSE_IBIS successful.
# -------------------------
# 5160: JBEM_IBIS requesting. data retrieval complete.
# JBEM_IBIS successful.
# -------------------------
# 5161: DBXV_IBIS requesting. data retrieval complete.
# DBXV_IBIS successful.
# -------------------------
# 5162: X0BA_IBIS requesting. data retrieval complete.
# X0BA_IBIS successful.
# -------------------------
# 5163: EUHA_IBIS requesting. data retrieval complete.
# EUHA_IBIS successful.
# -------------------------
# 5164: X13G_IBIS requesting. data retrieval complete.
# X13G_IBIS successful.
# -------------------------
# 5165: VECA_IBIS requesting. data retrieval complete.
# VECA_IBIS successful.
# -------------------------
# 5166: NDXH_IBIS requesting. data retrieval complete.
# NDXH_IBIS successful.
# -------------------------
# 5167: DBZN_IBIS requesting. data retrieval complete.
# DBZN_IBIS successful.
# -------------------------
# 5168: CU5_IBIS requesting. data retrieval complete.
# CU5_IBIS successful.
# -------------------------
# 5169: XDEP_IBIS requesting. data retrieval complete.
# XDEP_IBIS successful.
# -------------------------
# 5170: EISR_IBIS requesting. data retrieval complete.
# EISR_IBIS successful.
# -------------------------
# 5171: OD73_IBIS requesting. OD73_IBIS Error:162_Historical Market Data Service error message:No market data permissions for SWB STK
# -------------------------
# 5172: NGXS_IBIS requesting. data retrieval complete.
# NGXS_IBIS successful.
# -------------------------
# 5173: X509_IBIS requesting. data retrieval complete.
# X509_IBIS successful.
# -------------------------
# 5174: C077_IBIS requesting. data retrieval complete.
# C077_IBIS successful.
# -------------------------
# 5175: EXV1_IBIS requesting. data retrieval complete.
# EXV1_IBIS successful.
# -------------------------
# 5176: D5BE_IBIS requesting. data retrieval complete.
# D5BE_IBIS successful.
# -------------------------
# 5177: LCUJ_IBIS requesting. data retrieval complete.
# LCUJ_IBIS successful.
# -------------------------
# 5178: UEFR_IBIS requesting. data retrieval complete.
# UEFR_IBIS successful.
# -------------------------
# 5179: X0BG_IBIS requesting. data retrieval complete.
# X0BG_IBIS successful.
# -------------------------
# 5180: X00T_IBIS requesting. data retrieval complete.
# X00T_IBIS successful.
# -------------------------
# 5181: EEMK_IBIS requesting. data retrieval complete.
# EEMK_IBIS successful.
# -------------------------
# 5182: X009_IBIS requesting. data retrieval complete.
# X009_IBIS successful.
# -------------------------
# 5183: XDND_IBIS requesting. data retrieval complete.
# XDND_IBIS successful.
# -------------------------
# 5184: C8M_IBIS requesting. data retrieval complete.
# C8M_IBIS successful.
# -------------------------
# 5185: DX2Z_IBIS requesting. data retrieval complete.
# DX2Z_IBIS successful.
# -------------------------
# 5186: MOED_IBIS requesting. data retrieval complete.
# MOED_IBIS successful.
# -------------------------
# 5187: ETLK_IBIS requesting. data retrieval complete.
# ETLK_IBIS successful.
# -------------------------
# 5188: LYY8_IBIS requesting. data retrieval complete.
# LYY8_IBIS successful.
# -------------------------
# 5189: OD7P_IBIS requesting. data retrieval complete.
# OD7P_IBIS successful.
# -------------------------
# 5190: M9SC_IBIS requesting. data retrieval complete.
# M9SC_IBIS successful.
# -------------------------
# 5191: WTEZ_IBIS requesting. data retrieval complete.
# WTEZ_IBIS successful.
# -------------------------
# 5192: TNO_IBIS requesting. data retrieval complete.
# TNO_IBIS successful.
# -------------------------
# 5193: ESM_IBIS requesting. data retrieval complete.
# ESM_IBIS successful.
# -------------------------
# 5194: DBX7_IBIS requesting. data retrieval complete.
# DBX7_IBIS successful.
# -------------------------
# 5195: DVEU_IBIS requesting. data retrieval complete.
# DVEU_IBIS successful.
# -------------------------
# 5196: 8H81_IBIS requesting. 8H81_IBIS Error:162_Historical Market Data Service error message:No market data permissions for SWB STK
# -------------------------
# 5197: X00E_IBIS requesting. data retrieval complete.
# X00E_IBIS successful.
# -------------------------
# 5198: DXSZ_IBIS requesting. data retrieval complete.
# DXSZ_IBIS successful.
# -------------------------
# 5199: EMOM_IBIS requesting. data retrieval complete.
# EMOM_IBIS successful.
# -------------------------
# 5200: TWN_IBIS requesting. data retrieval complete.
# TWN_IBIS successful.
# -------------------------
# 5201: EL4U_IBIS requesting. data retrieval complete.
# EL4U_IBIS successful.
# -------------------------
# 5202: MTX1_IBIS requesting. data retrieval complete.
# MTX1_IBIS successful.
# -------------------------
# 5203: US9S_IBIS requesting. data retrieval complete.
# US9S_IBIS successful.
# -------------------------
# 5204: GY3L_IBIS requesting. data retrieval complete.
# GY3L_IBIS successful.
# -------------------------
# 5205: KRW_IBIS requesting. data retrieval complete.
# KRW_IBIS successful.
# -------------------------
# 5206: MCEU_IBIS requesting. data retrieval complete.
# MCEU_IBIS successful.
# -------------------------
# 5207: OD7U_IBIS requesting. data retrieval complete.
# OD7U_IBIS successful.
# -------------------------
# 5208: AFRN_IBIS requesting. data retrieval complete.
# AFRN_IBIS successful.
# -------------------------
# 5209: H4ZW_IBIS requesting. data retrieval complete.
# H4ZW_IBIS successful.
# -------------------------
# 5210: E044_IBIS requesting. data retrieval complete.
# E044_IBIS successful.
# -------------------------
# 5211: XUEM_IBIS requesting. data retrieval complete.
# XUEM_IBIS successful.
# -------------------------
# 5212: 3QQQ_IBIS requesting. data retrieval complete.
# 3QQQ_IBIS successful.
# -------------------------
# 5213: TIP10D_IBIS requesting. data retrieval complete.
# TIP10D_IBIS successful.
# -------------------------
# 5214: X0BE_IBIS requesting. data retrieval complete.
# X0BE_IBIS successful.
# -------------------------
# 5215: UIMF_IBIS requesting. data retrieval complete.
# UIMF_IBIS successful.
# -------------------------
# 5216: PCFP_IBIS requesting. data retrieval complete.
# PCFP_IBIS successful.
# -------------------------
# 5217: X00U_IBIS requesting. data retrieval complete.
# X00U_IBIS successful.
# -------------------------
# 5218: PR1J_IBIS requesting. data retrieval complete.
# PR1J_IBIS successful.
# -------------------------
# 5219: INDGW_IBIS requesting. data retrieval complete.
# INDGW_IBIS successful.
# -------------------------
# 5220: DEL2_IBIS requesting. data retrieval complete.
# DEL2_IBIS successful.
# -------------------------
# 5221: OD7K_IBIS requesting. data retrieval complete.
# OD7K_IBIS successful.
# -------------------------
# 5222: X0B1_IBIS requesting. data retrieval complete.
# X0B1_IBIS successful.
# -------------------------
# 5223: H4ZM_IBIS requesting. data retrieval complete.
# H4ZM_IBIS successful.
# -------------------------
# 5224: EMEH_IBIS requesting. data retrieval complete.
# EMEH_IBIS successful.
# -------------------------
# 5225: CC1_IBIS requesting. data retrieval complete.
# CC1_IBIS successful.
# -------------------------
# 5226: XMWK_IBIS requesting. data retrieval complete.
# XMWK_IBIS successful.
# -------------------------
# 5227: X011_IBIS requesting. data retrieval complete.
# X011_IBIS successful.
# -------------------------
# 5228: EXI5_IBIS requesting. data retrieval complete.
# EXI5_IBIS successful.
# -------------------------
# 5229: X0D5_IBIS requesting. data retrieval complete.
# X0D5_IBIS successful.
# -------------------------
# 5230: 3E3S_IBIS requesting. data retrieval complete.
# 3E3S_IBIS successful.
# -------------------------
# 5231: WTIF_IBIS requesting. data retrieval complete.
# WTIF_IBIS successful.
# -------------------------
# 5232: X007_IBIS requesting. data retrieval complete.
# X007_IBIS successful.
# -------------------------
# 5233: C031_IBIS requesting. data retrieval complete.
# C031_IBIS successful.
# -------------------------
# 5234: LYPT_IBIS requesting. data retrieval complete.
# LYPT_IBIS successful.
# -------------------------
# 5235: OD7S_IBIS requesting. data retrieval complete.
# OD7S_IBIS successful.
# -------------------------
# 5236: DX2I_IBIS requesting. data retrieval complete.
# DX2I_IBIS successful.
# -------------------------
# 5237: MSE_IBIS requesting. data retrieval complete.
# MSE_IBIS successful.
# -------------------------
# 5238: XUCS_IBIS requesting. data retrieval complete.
# XUCS_IBIS successful.
# -------------------------
# 5239: XDEV_IBIS requesting. data retrieval complete.
# XDEV_IBIS successful.
# -------------------------
# 5240: MAA_IBIS requesting. data retrieval complete.
# MAA_IBIS successful.
# -------------------------
# 5241: XMAW_IBIS requesting. data retrieval complete.
# XMAW_IBIS successful.
# -------------------------
# 5242: XETC_IBIS requesting. data retrieval complete.
# XETC_IBIS successful.
# -------------------------
# 5243: X0CB_IBIS requesting. data retrieval complete.
# X0CB_IBIS successful.
# -------------------------
# 5244: 500H_IBIS requesting. data retrieval complete.
# 500H_IBIS successful.
# -------------------------
# 5245: OD7E_IBIS requesting. data retrieval complete.
# OD7E_IBIS successful.
# -------------------------
# 5246: CI3_IBIS requesting. data retrieval complete.
# CI3_IBIS successful.
# -------------------------
# 5247: VZLA_IBIS requesting. data retrieval complete.
# VZLA_IBIS successful.
# -------------------------
# 5248: CAMX_IBIS requesting. data retrieval complete.
# CAMX_IBIS successful.
# -------------------------
# 5249: 8523_IBIS requesting. data retrieval complete.
# 8523_IBIS successful.
# -------------------------
# 5250: HSI_IBIS requesting. data retrieval complete.
# HSI_IBIS successful.
# -------------------------
# 5251: X0DB_IBIS requesting. data retrieval complete.
# X0DB_IBIS successful.
# -------------------------
# 5252: UIMR_IBIS requesting. data retrieval complete.
# UIMR_IBIS successful.
# -------------------------
# 5253: X00X_IBIS requesting. data retrieval complete.
# X00X_IBIS successful.
# -------------------------
# 5254: XZW0_IBIS requesting. data retrieval complete.
# XZW0_IBIS successful.
# -------------------------
# 5255: H41I_IBIS requesting. data retrieval complete.
# H41I_IBIS successful.
# -------------------------
# 5256: EXV8_IBIS requesting. data retrieval complete.
# EXV8_IBIS successful.
# -------------------------
# 5257: EXX6_IBIS requesting. data retrieval complete.
# EXX6_IBIS successful.
# -------------------------
# 5258: TEL_IBIS requesting. data retrieval complete.
# TEL_IBIS successful.
# -------------------------
# 5259: O1LL_IBIS requesting. data retrieval complete.
# O1LL_IBIS successful.
# -------------------------
# 5260: C072_IBIS requesting. data retrieval complete.
# C072_IBIS successful.
# -------------------------
# 5261: X03C_IBIS requesting. data retrieval complete.
# X03C_IBIS successful.
# -------------------------
# 5262: X04K_IBIS requesting. data retrieval complete.
# X04K_IBIS successful.
# -------------------------
# 5263: UIMT_IBIS requesting. data retrieval complete.
# UIMT_IBIS successful.
# -------------------------
# 5264: EJP51_IBIS requesting. EJP51_IBIS Error:200_No security definition has been found for the request
# -------------------------
# 5265: XYLD_IBIS requesting. data retrieval complete.
# XYLD_IBIS successful.
# -------------------------
# 5266: XDGM_IBIS requesting. data retrieval complete.
# XDGM_IBIS successful.
# -------------------------
# 5267: XCHA_IBIS requesting. data retrieval complete.
# XCHA_IBIS successful.
# -------------------------
# 5268: X04G_IBIS requesting. data retrieval complete.
# X04G_IBIS successful.
# -------------------------
# 5269: AFLE_IBIS requesting. data retrieval complete.
# AFLE_IBIS successful.
# -------------------------
# 5270: EXSA_IBIS requesting. data retrieval complete.
# EXSA_IBIS successful.
# -------------------------
# 5271: X0C0_IBIS requesting. data retrieval complete.
# X0C0_IBIS successful.
# -------------------------
# 5272: GY3S_IBIS requesting. data retrieval complete.
# GY3S_IBIS successful.
# -------------------------
# 5273: UIMY_IBIS requesting. data retrieval complete.
# UIMY_IBIS successful.
# -------------------------
# 5274: ULOVE_IBIS requesting. data retrieval complete.
# ULOVE_IBIS successful.
# -------------------------
# 5275: 5CH3_IBIS requesting. 5CH3_IBIS Error:200_No security definition has been found for the request
# -------------------------
# 5276: C079_IBIS requesting. data retrieval complete.
# C079_IBIS successful.
# -------------------------
# 5277: XUFN_IBIS requesting. data retrieval complete.
# XUFN_IBIS successful.
# -------------------------
# 5278: 9GAH_IBIS requesting. 9GAH_IBIS Error:200_No security definition has been found for the request
# -------------------------
# 5279: DXIBX_IBIS requesting. DXIBX_IBIS Error:162_Historical Market Data Service error message:No market data permissions for BM STK
# -------------------------
# 5280: EXXY_IBIS requesting. data retrieval complete.
# EXXY_IBIS successful.
# -------------------------
# 5281: BNQV_IBIS requesting. data retrieval complete.
# BNQV_IBIS successful.
# -------------------------
# 5282: X0CA_IBIS requesting. data retrieval complete.
# X0CA_IBIS successful.
# -------------------------
# 5283: WTEU_IBIS requesting. data retrieval complete.
# WTEU_IBIS successful.
# -------------------------
# 5284: UEQ7_IBIS requesting. data retrieval complete.
# UEQ7_IBIS successful.
# -------------------------
# 5285: WTIC_IBIS requesting. data retrieval complete.
# WTIC_IBIS successful.
# -------------------------
# 5286: XGII_IBIS requesting. data retrieval complete.
# XGII_IBIS successful.
# -------------------------
# 5287: OD7X_IBIS requesting. data retrieval complete.
# OD7X_IBIS successful.
# -------------------------
# 5288: XD5F_IBIS requesting. data retrieval complete.
# XD5F_IBIS successful.
# -------------------------
# 5289: B4NU_IBIS requesting. data retrieval complete.
# B4NU_IBIS successful.
# -------------------------
# 5290: 4RUE_IBIS requesting. data retrieval complete.
# 4RUE_IBIS successful.
# -------------------------
# 5291: OD7W_IBIS requesting. data retrieval complete.
# OD7W_IBIS successful.
# -------------------------
# 5292: DXSW_IBIS requesting. data retrieval complete.
# DXSW_IBIS successful.
# -------------------------
# 5293: EL4G_IBIS requesting. data retrieval complete.
# EL4G_IBIS successful.
# -------------------------
# 5294: PVXT_IBIS requesting. data retrieval complete.
# PVXT_IBIS successful.
# -------------------------
# 5295: OI1S_IBIS requesting. OI1S_IBIS Error:200_No security definition has been found for the request
# -------------------------
# 5296: 0LJF_IBIS requesting. 0LJF_IBIS Error:200_No security definition has been found for the request
# -------------------------
# 5297: X0B5_IBIS requesting. data retrieval complete.
# X0B5_IBIS successful.
# -------------------------
# 5298: DBX3_IBIS requesting. DBX3_IBIS Error:200_No security definition has been found for the request
# -------------------------
# 5299: MIVU_IBIS requesting. data retrieval complete.
# MIVU_IBIS successful.
# -------------------------
# 5300: X0DH_IBIS requesting. data retrieval complete.
# X0DH_IBIS successful.
# -------------------------
# 5301: BNQ9_IBIS requesting. data retrieval complete.
# BNQ9_IBIS successful.
# -------------------------
# 5302: PR1U_IBIS requesting. data retrieval complete.
# PR1U_IBIS successful.
# -------------------------
# 5303: ECB_IBIS requesting. data retrieval complete.
# ECB_IBIS successful.
# -------------------------
# 5304: VX5E_IBIS requesting. data retrieval complete.
# VX5E_IBIS successful.
# -------------------------
# 5305: BNQU_IBIS requesting. data retrieval complete.
# BNQU_IBIS successful.
# -------------------------
# 5306: WTED_IBIS requesting. data retrieval complete.
# WTED_IBIS successful.
# -------------------------
# 5307: ASI_IBIS requesting. data retrieval complete.
# ASI_IBIS successful.
# -------------------------
# 5308: X0D2_IBIS requesting. data retrieval complete.
# X0D2_IBIS successful.
# -------------------------
# 5309: UIMP_IBIS requesting. data retrieval complete.
# UIMP_IBIS successful.
# -------------------------
# 5310: LYX7_IBIS requesting. data retrieval complete.
# LYX7_IBIS successful.
# -------------------------
# 5311: E908_IBIS requesting. data retrieval complete.
# E908_IBIS successful.
# -------------------------
# 5312: X00D_IBIS requesting. data retrieval complete.
# X00D_IBIS successful.
# -------------------------
# 5313: AEMD_IBIS requesting. data retrieval complete.
# AEMD_IBIS successful.
# -------------------------
# 5314: MD4X_IBIS requesting. data retrieval complete.
# MD4X_IBIS successful.
# -------------------------
# 5315: 4RTR_IBIS requesting. data retrieval complete.
# 4RTR_IBIS successful.
# -------------------------
# 5316: DXSB_IBIS requesting. data retrieval complete.
# DXSB_IBIS successful.
# -------------------------
# 5317: 3E3M_IBIS requesting. data retrieval complete.
# 3E3M_IBIS successful.
# -------------------------
# 5318: EXX1_IBIS requesting. data retrieval complete.
# EXX1_IBIS successful.
# -------------------------
# 5319: 10AM_IBIS requesting. data retrieval complete.
# 10AM_IBIS successful.
# -------------------------
# 5320: X0CW_IBIS requesting. data retrieval complete.
# X0CW_IBIS successful.
# -------------------------
# 5321: X0B3_IBIS requesting. data retrieval complete.
# X0B3_IBIS successful.
# -------------------------
# 5322: XBJJ_IBIS requesting. data retrieval complete.
# XBJJ_IBIS successful.
# -------------------------
#
# ******** All done. ********
# True

# %%
 # Manual disconnection of connection object
    
con.disconnect()
# Out:
# True

# %% [markdown]
# # Enhancements
#
# ### Speedup
# - download next contract as soon as data is in file
#
# ### Extra features for downloading
# - check for splits/mergers
# - Stream logger for status messages
#
# ### Symbol in multiple exchanges
# - if symbol is multiple times in list
#     - load data from primary exchange if ppossible
#     - if primary is not available, load from exchange with highest average (price-)volume
#
# ### contracts database
# - pull contracts from ib webpage
# - pull contracts data from ib
# - abillity to create own univestes (=contracts lists) based on contracts data
#
# ### Storage of price data
# - store price data in database? sqlite, as handeled in one file? InfluxDB?
# - cloud storage of data
#
# ### Misc
# -
