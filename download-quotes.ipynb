# %%
symbols = []

file = open('xetra_etf_symbols.txt','r') 
for line in file:
    symbols.append(line.rstrip())
file.close()

symbols
# Out:
# ['DBXD.DE',
#  'DXSN.DE',
#  'DBPD.DE',
#  'DBPE.DE',
#  '4BRZ.DE',
#  'SMLP.DE',
#  'SMLD.DE',
#  'WTEB.DE',
#  'WTI2.DE',
#  'UEQ3.DE',
#  'UBUB.DE',
#  'SPY5.DE',
#  'SYBX.DE',
#  'UBUD.DE',
#  'SYBI.DE',
#  'UIQI.DE',
#  'ZPRE.DE',
#  'XDWY.DE',
#  'OM3X.DE',
#  'XQUE.DE',
#  'XMDU.DE',
#  'XMVE.DE',
#  'XUHY.DE',
#  'SPFU.DE',
#  'SPFB.DE',
#  'TRDE.DE',
#  'OWLU.DE',
#  'PSFE.DE',
#  '5HED.DE',
#  'XYLE.DE',
#  'XZEU.DE',
#  'XZMU.DE',
#  'SGAJ.DE',
#  'SPFA.DE',
#  'FVSJ.DE',
#  'OM3M.DE',
#  'SPPW.DE',
#  'XD9E.DE',
#  'IU0E.DE',
#  'AYEP.DE',
#  'XDPD.DE',
#  'IBCC.DE',
#  'XUEK.DE',
#  'XAIX.DE',
#  'XMOV.DE',
#  'DEAM.DE',
#  'S5SD.DE',
#  'S5SG.DE',
#  'EDM4.DE',
#  'EDMJ.DE',
#  'EDMW.DE',
#  'EDM6.DE',
#  'EDMU.DE',
#  'XDWL.DE',
#  'XDWH.DE',
#  'XDWF.DE',
#  'XDW0.DE',
#  'XDWS.DE',
#  'XDWC.DE',
#  'XDWU.DE',
#  'XWTS.DE',
#  'XDWM.DE',
#  'XDWT.DE',
#  'XDWI.DE',
#  'XDNY.DE',
#  'XGLF.DE',
#  'XDNE.DE',
#  'NS4E.DE',
#  'XDEP.DE',
#  'XMGD.DE',
#  'XESQ.DE',
# ...

# %%
from yahoo_historical import Fetcher

_START_DATE = [2007,1,1]
_END_DATE = [2017,1,1]

data = Fetcher('UIMP.DE', _START_DATE, _END_DATE)
print(data.getHistorical())
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2011-10-06  39.549999  39.549999  39.549999  39.549999  39.549999
# 1     2011-10-07        NaN        NaN        NaN        NaN        NaN
# 2     2011-10-10  39.980000  39.980000  39.980000  39.980000  39.980000
# 3     2011-10-11        NaN        NaN        NaN        NaN        NaN
# 4     2011-10-12  40.270000  40.270000  40.270000  40.270000  40.270000
# 5     2011-10-13        NaN        NaN        NaN        NaN        NaN
# 6     2011-10-14        NaN        NaN        NaN        NaN        NaN
# 7     2011-10-17        NaN        NaN        NaN        NaN        NaN
# 8     2011-10-18  40.160000  40.160000  40.160000  40.160000  40.160000
# 9     2011-10-19  40.470001  40.470001  40.470001  40.470001  40.470001
# 10    2011-10-20        NaN        NaN        NaN        NaN        NaN
# 11    2011-10-21        NaN        NaN        NaN        NaN        NaN
# ...
